# %%
#!pip install psycopg2
#import psycopg2 as ps
# !pip install pandas
import pandas as pd
# !pip install networkx
import networkx as nx
# !pip install matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# !pip install python-louvain
from community import community_louvain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/nikola/Library/Python/3.8/lib/python/site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in /Users/nikola/Library/Python/3.8/lib/python/site-packages (2.8.5)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/nikola/Library/Python/3.8/lib/python/site-packages (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (4.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-louvain in /Users/nikola/Library/Python/3.8/lib/python/site-packages (0.16)
# Requirement already satisfied: networkx in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from python-louvain) (2.8.5)
# Requirement already satisfied: numpy in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from python-louvain) (1.23.2)

# %%
drive_path = 'data/'

# %%
#df_response = pd.read_csv(drive_path+'CRORIS_df_response.csv', index_col=0) 
df_ustanova = pd.read_csv(drive_path+'CRORIS_df_ustanova.csv', index_col=0) 
df_osoba = pd.read_csv(drive_path+'CRORIS_df_osoba.csv', index_col=0) 
df_projekt = pd.read_csv(drive_path+'CRORIS_df_projekt.csv', index_col=0) 
df_financijer = pd.read_csv(drive_path+'CRORIS_df_financijer.csv', index_col=0) 
df_osoba_projekt = pd.read_csv(drive_path+'CRORIS_df_osoba_projekt.csv', index_col=0) 
df_projekt_financijer = pd.read_csv(drive_path+'CRORIS_df_projekt_financijer.csv', index_col=0) 
df_projekt_tip = pd.read_csv(drive_path+'CRORIS_df_projekt_tip.csv', index_col=0) 
df_projekt_ustanova = pd.read_csv(drive_path+'CRORIS_df_projekt_ustanova.csv', index_col=0)

# %%
df_osoba_projekt
# Out:
#        osoba_id  projekt_id     pocetak        kraj        projektnaUloga  \
# 0          5511           1  01.09.2015  09.01.2019              voditelj
# 1          4292           2  01.09.2015  09.01.2019              suradnik
# 2          6894           2  01.09.2015  09.01.2019              suradnik
# 3         15606           2  01.09.2015  09.01.2019              voditelj
# 4         18553           2  01.09.2015  09.01.2019              suradnik
# ...         ...         ...         ...         ...                   ...
# 22500     34728        7749  01.12.2021  30.09.2022              voditelj
# 22501     39075        7749  01.12.2021  30.09.2022              suradnik
# 22502     30703        7750  01.12.2021  06.05.2022              voditelj
# 22503     21999        7752  01.07.2018  01.07.2020  voditelj na ustanovi
# 22504      5518        7755  01.10.2021  30.09.2024  voditelj na ustanovi
#
#                           created
# 0      2022-08-18 16:01:13.287432
# 1      2022-08-18 16:01:15.157369
# 2      2022-08-18 16:01:15.157369
# 3      2022-08-18 16:01:15.157369
# 4      2022-08-18 16:01:15.157369
# ...                           ...
# 22500  2022-08-18 19:55:35.400415
# 22501  2022-08-18 19:55:35.400415
# 22502  2022-08-18 19:55:37.212435
# 22503  2022-08-18 19:55:40.667108
# 22504  2022-08-18 19:55:45.809604
#
# [22477 rows x 6 columns]

# %% [markdown]
# df = df_osoba_projekt.merge(df_osoba, left_on='osoba_id', right_on='id')
# df = df.merge(df_ustanova, left_on='ustanovaId', right_on='id')
# df = df.merge(df_projekt, left_on='projekt_id', right_on='id', suffixes=('_l', '_r'))
# df = df.drop_duplicates(subset='osoba_id')
# df = df[['osoba_id', 'projekt_id', 'ime', 'prezime', 'ustanovaId', 'mbu', 'ustanovaNaziv', 'aaiDomain', 'acro', 'title', 'currencyCode', 'totalCost']]

# %%
df = df_osoba_projekt.merge(df_osoba, left_on='osoba_id', right_on='id')
df = df[['osoba_id', 'projekt_id', 'ime', 'prezime', 'ustanovaId']]

# %%
df
# Out:
#        osoba_id  projekt_id      ime    prezime  ustanovaId
# 0          5511           1  Tihomir      Balog        66.0
# 1          5511        1710  Tihomir      Balog        66.0
# 2          5511        5661  Tihomir      Balog        66.0
# 3          5511        6303  Tihomir      Balog        66.0
# 4          5511        6304  Tihomir      Balog        66.0
# ...         ...         ...      ...        ...         ...
# 22472     35924        7740    Ivana    Radonić         1.0
# 22473     40019        7741    Ivana  Karamatić         NaN
# 22474     28241        7742   Marina    Diković       255.0
# 22475     22698        7747  Božidar     Petrač       129.0
# 22476      5518        7755    Bojan      Hamer        66.0
#
# [22477 rows x 5 columns]

# %%
G = nx.Graph()

# %%
len_df = len(df)

for index, row in df.iterrows():
  G.add_node(row[0], ime = row[2], prezime = row[3], ustanova = row[4])

  c=0 # broj veza
  for i, r in df.iterrows(): # iteriraj po retcima u petlji za svaki dodani novi node
    if r[1] == row[1]: # ako projekt iteriranog retka jednak pocetnom dodaj im edge
      if r[0] != row[0]: # izbjegni stvaranje edga za istu osobu (selfloop)
        G.add_edge(row[0], r[0], projekt = r[1])
        c += 1 # uvecaj broj veza za 1
  progress = '{0:.3g}'.format((index/len_df)*100)
  print(str(progress)+'% - Index: '+str(index)+'; Osoba: '+str(row[0])+'; Projekt: '+str(row[1])+'; Broj veza: '+str(c))
# Out:
# 0% - Index: 0; Osoba: 5511; Projekt: 1; Broj veza: 0
# 0.00445% - Index: 1; Osoba: 5511; Projekt: 1710; Broj veza: 0
# 0.0089% - Index: 2; Osoba: 5511; Projekt: 5661; Broj veza: 0
# 0.0133% - Index: 3; Osoba: 5511; Projekt: 6303; Broj veza: 8
# 0.0178% - Index: 4; Osoba: 5511; Projekt: 6304; Broj veza: 0
# 0.0222% - Index: 5; Osoba: 4292; Projekt: 2; Broj veza: 7
# 0.0267% - Index: 6; Osoba: 4292; Projekt: 1812; Broj veza: 0
# 0.0311% - Index: 7; Osoba: 4292; Projekt: 3679; Broj veza: 8
# 0.0356% - Index: 8; Osoba: 6894; Projekt: 2; Broj veza: 7
# 0.04% - Index: 9; Osoba: 15606; Projekt: 2; Broj veza: 7
# 0.0445% - Index: 10; Osoba: 15606; Projekt: 1813; Broj veza: 0
# 0.0489% - Index: 11; Osoba: 15606; Projekt: 3679; Broj veza: 8
# 0.0534% - Index: 12; Osoba: 15606; Projekt: 7459; Broj veza: 1
# 0.0578% - Index: 13; Osoba: 18553; Projekt: 2; Broj veza: 7
# 0.0623% - Index: 14; Osoba: 18553; Projekt: 1811; Broj veza: 0
# 0.0667% - Index: 15; Osoba: 20195; Projekt: 2; Broj veza: 7
# 0.0712% - Index: 16; Osoba: 20195; Projekt: 1731; Broj veza: 10
# 0.0756% - Index: 17; Osoba: 29599; Projekt: 2; Broj veza: 7
# 0.0801% - Index: 18; Osoba: 29599; Projekt: 3679; Broj veza: 8
# 0.0845% - Index: 19; Osoba: 31623; Projekt: 2; Broj veza: 7
# 0.632% - Index: 142; Osoba: 1715; Projekt: 6499; Broj veza: 7
# 0.636% - Index: 143; Osoba: 1715; Projekt: 6501; Broj veza: 2
# 0.641% - Index: 144; Osoba: 1715; Projekt: 6508; Broj veza: 2
# 0.645% - Index: 145; Osoba: 1715; Projekt: 6531; Broj veza: 7
# 0.65% - Index: 146; Osoba: 1715; Projekt: 6538; Broj veza: 7
# 0.654% - Index: 147; Osoba: 2751; Projekt: 19; Broj veza: 12
# 0.658% - Index: 148; Osoba: 2751; Projekt: 6501; Broj veza: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [267], in <cell line: 3>()
#       6 c=0 # broj veza
#       7 for i, r in df.iterrows(): # iteriraj po retcima u petlji za svaki dodani novi node
# ----> 8   if r[1] == row[1]: # ako projekt iteriranog retka jednak pocetnom dodaj im edge
#       9     if r[0] != row[0]: # izbjegni stvaranje edga za istu osobu (selfloop)
#      10       G.add_edge(row[0], r[0], projekt = r[1])
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py:955, in Series.__getitem__(self, key)
#     952     key = unpack_1tuple(key)
#     954 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 955     return self._values[key]
#     957 elif key_is_scalar:
#     958     return self._get_value(key)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py:687, in Series._values(self)
#     647     """
#     648     Return Series as ndarray or ndarray-like depending on the dtype.
#     649
#    (...)
#     683            '2013-01-03T05:00:00.000000000'], dtype='datetime64[ns]')
#     684     """
#     685     return self._mgr.external_values()
# --> 687 @property
#     688 def _values(self):
#     689     """
#     690     Return the internal repr of this data (defined by Block.interval_values).
#     691     This are the values as stored in the Block (ndarray or ExtensionArray
#    (...)
#     717
#     718     """
#     719     return self._mgr.internal_values()
#
# KeyboardInterrupt:

# %%
T = G

# %%
nx.draw_networkx(G)
plt.show()

# %%
centered = nx.Graph(nx.ego_graph(G, 388162, radius = 2)) # 388162 nikola, 10389 mile,
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# Input In [269], in <cell line: 1>()
# ----> 1 centered = nx.Graph(nx.ego_graph(G, 388162, radius = 2))
#
# File ~/Library/Python/3.8/lib/python/site-packages/networkx/generators/ego.py:59, in ego_graph(G, n, radius, center, undirected, distance)
#      57         sp, _ = nx.single_source_dijkstra(G, n, cutoff=radius, weight=distance)
#      58     else:
# ---> 59         sp = dict(nx.single_source_shortest_path_length(G, n, cutoff=radius))
#      61 H = G.subgraph(sp).copy()
#      62 if not center:
#
# File ~/Library/Python/3.8/lib/python/site-packages/networkx/algorithms/shortest_paths/unweighted.py:55, in single_source_shortest_path_length(G, source, cutoff)
#      19 """Compute the shortest path lengths from source to all reachable nodes.
#      20
#      21 Parameters
#    (...)
#      52 shortest_path_length
#      53 """
#      54 if source not in G:
# ---> 55     raise nx.NodeNotFound(f"Source {source} is not in G")
#      56 if cutoff is None:
#      57     cutoff = float("inf")
#
# NodeNotFound: Source 388162 is not in G

# %%
plt.figure(2,figsize=(15,10))
nx.draw_networkx(centered)
plt.show()

# %%
nx.degree_centrality(G)
# Out:
# {5511: 0.0,
#  4292: 0.03954802259887005,
#  6894: 0.03954802259887005,
#  15606: 0.03954802259887005,
#  18553: 0.03954802259887005,
#  20195: 0.03954802259887005,
#  29599: 0.03954802259887005,
#  31623: 0.03954802259887005,
#  33639: 0.03954802259887005,
#  3729: 0.0,
#  27220: 0.0,
#  38087: 0.0,
#  1559: 0.0,
#  26060: 0.0,
#  1934: 0.0,
#  3816: 0.0,
#  38088: 0.0,
#  5129: 0.0,
#  2842: 0.0,
#  3805: 0.0,
#  3322: 0.0,
#  2987: 0.0,
#  4305: 0.0,
#  2424: 0.0,
#  526: 0.005649717514124294,
#  38092: 0.005649717514124294,
#  4424: 0.0,
#  3226: 0.0,
#  30952: 0.0,
#  15196: 0.0,
#  8842: 0.03954802259887005,
#  11939: 0.03954802259887005,
#  23646: 0.03954802259887005,
#  26487: 0.03954802259887005,
#  31277: 0.03954802259887005,
#  31577: 0.03954802259887005,
#  32218: 0.03954802259887005,
#  38099: 0.03954802259887005,
#  38106: 0.0,
#  26967: 0.0,
#  28754: 0.0,
#  7602: 0.0,
#  28752: 0.0,
#  21789: 0.0,
#  29258: 0.0,
#  21269: 0.0,
#  30614: 0.0,
#  27211: 0.0,
#  21931: 0.0,
#  23876: 0.0,
#  27887: 0.0,
#  28564: 0.0,
#  22752: 0.0,
#  22005: 0.0,
#  26267: 0.0,
#  5687: 0.0,
#  3653: 0.0,
#  17389: 0.0,
#  9309: 0.0,
#  25113: 0.0,
#  11767: 0.0,
#  20023: 0.0,
#  17823: 0.0,
#  5619: 0.0}

# %%
print ('Number of nodes: ', G.size())
print ('Number of edges: ', G.order())
# Out:
# Number of nodes:  203
# Number of edges:  178

# %% [markdown]
# 10174 nodes
# 66803 edges

# %%
btwncnt = nx.betweenness_centrality(G)

# %%
# Uses Louvain algorithm - References large networks. J. Stat. Mech 10008, 1-12(2008).
partition = community_louvain.best_partition(centered)
values = [partition.get(node) for node in centered.nodes()]

# %%
# draw the graph
pos = nx.spring_layout(centered)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(centered, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(centered, pos, alpha=0.5)
plt.show()

# %%
dendo = community_louvain.generate_dendrogram(centered)
import numpy as np
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt

for level in range(len(dendo) - 1) :
    print("partition at level", level, "is", community_louvain.partition_at_level(dendo, level))

# %%
K = centered
pos = nx.fruchterman_reingold_layout(K);
plt.figure(figsize=(8,8));
plt.axis("off");
nx.draw_networkx_nodes(K, pos, node_size=300, node_color="black");
nx.draw_networkx_edges(K, pos, alpha=0.500);
nx.draw_networkx_labels(K, pos, font_color="white");
plt.show();

# %%
# https://notebook.community/eflegara/NetStruc/6.%20Community%20Detection
import operator
## For Hierarchical Clustering
from scipy.cluster import hierarchy
from scipy.spatial import distance
    
#order the dictionary by value, which is the edge betweeness of two nodes
ebet = nx.edge_betweenness_centrality(K)
sorted_ebet = sorted(ebet.items(), key=operator.itemgetter(1), reverse=True)
sorted_ebet[0:5]
# Out:
# [((20195, 4292), 0.03571428571428571),
#  ((20195, 6894), 0.03571428571428571),
#  ((20195, 15606), 0.03571428571428571),
#  ((20195, 18553), 0.03571428571428571),
#  ((20195, 29599), 0.03571428571428571)]

# %% [markdown]
# https://towardsdatascience.com/louvains-algorithm-for-community-detection-in-python-95ff7f675306

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos, node_size = 75, alpha = 0.8)
plt.show()
