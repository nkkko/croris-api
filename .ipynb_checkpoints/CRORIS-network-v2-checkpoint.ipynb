# %%
# !pip install pandas
import pandas as pd
# !pip install networkx
import networkx as nx
# !pip install matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# !pip install python-louvain
from community import community_louvain

drive_path = 'data/'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/nikola/Library/Python/3.8/lib/python/site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in /Users/nikola/Library/Python/3.8/lib/python/site-packages (2.8.5)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/nikola/Library/Python/3.8/lib/python/site-packages (3.5.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (4.36.0)
# Requirement already satisfied: packaging>=20.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-louvain in /Users/nikola/Library/Python/3.8/lib/python/site-packages (0.16)
# Requirement already satisfied: networkx in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from python-louvain) (2.8.5)
# Requirement already satisfied: numpy in /Users/nikola/Library/Python/3.8/lib/python/site-packages (from python-louvain) (1.23.2)

# %%
#df_response = pd.read_csv(drive_path+'CRORIS_df_response.csv', index_col=0) 
df_ustanova = pd.read_csv(drive_path+'CRORIS_df_ustanova.csv', index_col=0) 
df_osoba = pd.read_csv(drive_path+'CRORIS_df_osoba.csv', index_col=0) 
df_projekt = pd.read_csv(drive_path+'CRORIS_df_projekt.csv', index_col=0) 
df_financijer = pd.read_csv(drive_path+'CRORIS_df_financijer.csv', index_col=0) 
df_osoba_projekt = pd.read_csv(drive_path+'CRORIS_df_osoba_projekt.csv', index_col=0) 
df_projekt_financijer = pd.read_csv(drive_path+'CRORIS_df_projekt_financijer.csv', index_col=0) 
df_projekt_tip = pd.read_csv(drive_path+'CRORIS_df_projekt_tip.csv', index_col=0) 
df_projekt_ustanova = pd.read_csv(drive_path+'CRORIS_df_projekt_ustanova.csv', index_col=0)

# %%
# https://glowingpython.blogspot.com/2012/11/first-steps-with-networx.html?m=1
def trim_nodes(G,d):
    """ returns a copy of G without 
     the nodes with a degree less than d """
    Gt = G.copy()
    dn = nx.degree(Gt)

    remove = [node for node,degree in dict(Gt.degree()).items() if dn[node] <= d]

    Gt.remove_nodes_from(remove)
    return Gt

# %%
# https://glowingpython.blogspot.com/2013/02/betweenness-centrality.html
def most_important(G):
    """ returns a copy of G with
     the most important nodes
     according to the pagerank """ 
    ranking = nx.betweenness_centrality(G).items()
    #print(ranking)
    r = [x[1] for x in ranking]
    m = sum(r)/len(r) # mean centrality
    t = m*3 # threshold, we keep only the nodes with 3 times the mean
    Gt = G.copy()
    for k, v in ranking:
        if v < t:
            Gt.remove_node(k)
    return Gt

# %%
# self-join to create edges df
df = df_osoba_projekt.merge(right=df_osoba_projekt, how='left', on='projekt_id')
df = df.drop_duplicates(subset=['osoba_id_x', 'projekt_id', 'osoba_id_y'])
# df = df[df['osoba_id_x'] != df['osoba_id_y']] # remove selfloops
df = df.merge(df_projekt, left_on='projekt_id', right_on='id', suffixes=('_l', '_r'))

# conversion from HRK to EUR
for index, row in df.iterrows():
    if row['currencyCode'] == 'HRK':
        df.at[index, 'totalCost'] = row['totalCost']/7.5

df = df[['osoba_id_x', 'osoba_id_y', 'projekt_id', 'acro', 'title', 'totalCost']]
df
#df.query('osoba_id_x == 7101') #test
# Out:
#         osoba_id_x  osoba_id_y  projekt_id      acro  \
# 0             5511        5511           1    SuMERA
# 1             4292        4292           2   SERT-OB
# 2             4292        6894           2   SERT-OB
# 3             4292       15606           2   SERT-OB
# 4             4292       18553           2   SERT-OB
# ...            ...         ...         ...       ...
# 183968       39075       34728        7749   AAS RSS
# 183969       39075       39075        7749   AAS RSS
# 183970       30703       30703        7750      EUPB
# 183971       21999       21999        7752       NaN
# 183972        5518        5518        7755  MuMiFaST
#
#                                                     title     totalCost
# 0       Sirtuin3 kao posrednik mitohondrijske funkcije...  1.320337e+05
# 1       Serotonergična modulacija pretilosti: međuovis...  1.248133e+05
# 2       Serotonergična modulacija pretilosti: međuovis...  1.248133e+05
# 3       Serotonergična modulacija pretilosti: međuovis...  1.248133e+05
# 4       Serotonergična modulacija pretilosti: međuovis...  1.248133e+05
# ...                                                   ...           ...
# 183968  Aurelije Augustin, Soliloquia / Conversations ...  2.000000e+03
# 183969  Aurelije Augustin, Soliloquia / Conversations ...  2.000000e+03
# 183970  European Colloquium on Philosophy of Life Scie...  1.733333e+03
# 183971         Technological innovation center Virovitica  2.342881e+06
# 183972  Mussel Mitigation Feeds and Supply System Tech...  8.673000e+04
#
# [183973 rows x 6 columns]

# %%
# create a graph
G = nx.Graph()
G = nx.from_pandas_edgelist(df, 'osoba_id_x', 'osoba_id_y', ['projekt_id', 'acro', 'title', 'totalCost']) 
# get node attributed from df_osoba
node_attr = df_osoba.set_index('id').to_dict('index')
nx.set_node_attributes(G, node_attr)

print('No. of nodes: ', G.order())
print('No. of edges: ', G.size())
# Out:
# No. of nodes:  10174
# No. of edges:  76977

# %%
G.nodes[38162] # get node details
G.edges(38162) # get list of edge pairs
G[5511] # get full list of edges info
G[5511][168] # get exect edge with full info
list(G.edges(data=True)) # list all edges
# Out:
# [(4292,
#   6894,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   15606,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   18553,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   20195,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   29599,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (4292,
#   7341,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (4292,
#   33409,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (4292,
#   35493,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (4292,
#   37427,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (6894,
#   15606,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (6894,
#   18553,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (6894,
#   20195,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (6894,
#   29599,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (6894,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (6894,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   18553,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   20195,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   29599,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (15606,
#   7341,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (15606,
#   33409,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (15606,
#   35493,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (15606,
#   37427,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (15606,
#   15990,
#   {'projekt_id': 7459,
#    'acro': 'HERO',
#    'title': 'Skrb o zdravlju online',
#    'totalCost': 22000.0}),
#  (18553,
#   20195,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (18553,
#   29599,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (18553,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (18553,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (20195,
#   29599,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (20195,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (20195,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (20195,
#   1281,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   12124,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   14128,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   20023,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   22038,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   27405,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   29127,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   29598,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   30268,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (20195,
#   30792,
#   {'projekt_id': 1731,
#    'acro': nan,
#    'title': 'Scientific Visualisation Methods',
#    'totalCost': 0.0}),
#  (29599,
#   31623,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (29599,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (29599,
#   7341,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (29599,
#   33409,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (29599,
#   35493,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (29599,
#   37427,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (31623,
#   33639,
#   {'projekt_id': 2,
#    'acro': 'SERT-OB',
#    'title': 'Serotonergična modulacija pretilosti: međuovisnost regulatornih molekula i puteva',
#    'totalCost': 124813.33333333333}),
#  (31623,
#   7341,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (31623,
#   33409,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (31623,
#   35493,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (31623,
#   37427,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (33639,
#   7341,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (33639,
#   33409,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (33639,
#   35493,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (33639,
#   37427,
#   {'projekt_id': 3679,
#    'acro': 'PLANS',
#    'title': 'Utjecaj majčinog metaboličkog stanja na serotoninski sustav posteljice i neonatusa: od metilacije DNA do funkcije proteina',
#    'totalCost': 132000.0}),
#  (5572,
#   16420,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (5572,
#   27804,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (5572,
#   33390,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (16420,
#   27804,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (16420,
#   33390,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (16420,
#   3719,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   8672,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   8810,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   11017,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   28643,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   28645,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   30565,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   34556,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (16420,
#   38049,
#   {'projekt_id': 44,
#    'acro': 'GEOPROOFS',
#    'title': 'Kredni geodinamski dokazi u području Dinarida i Panonskog bazena',
#    'totalCost': 117834.66666666667}),
#  (27804,
#   33390,
#   {'projekt_id': 6,
#    'acro': 'NATURACI',
#    'title': 'Prirodno stanište klinički značajnih Acinetobacter baumannii',
#    'totalCost': 133228.0}),
#  (33390,
#   1643,
#   {'projekt_id': 4498,
#    'acro': 'ADRICOR',
#    'title': 'Utjecaj klimatskih promjena na bioraznolikost koralja - istraživanje slučaja masovnih ugibanja u Jadranskom moru',
#    'totalCost': 133123.33333333334}),
#  (33390,
#   5683,
#   {'projekt_id': 4498,
#    'acro': 'ADRICOR',
#    'title': 'Utjecaj klimatskih promjena na bioraznolikost koralja - istraživanje slučaja masovnih ugibanja u Jadranskom moru',
#    'totalCost': 133123.33333333334}),
#  (33390,
#   38795,
#   {'projekt_id': 4498,
#    'acro': 'ADRICOR',
#    'title': 'Utjecaj klimatskih promjena na bioraznolikost koralja - istraživanje slučaja masovnih ugibanja u Jadranskom moru',
#    'totalCost': 133123.33333333334}),
#  (1481,
#   2186,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   2220,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   13564,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   31037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   33037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (1481,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (1481,
#   3328,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (1481,
#   39212,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (1481,
#   28306,
#   {'projekt_id': 6383,
#    'acro': 'Arf & CMV',
#    'title': 'Stanični sustav Arf GTPaza u patogenezi citomegalovirusne infekcije',
#    'totalCost': 90533.33333333333}),
#  (1481,
#   39462,
#   {'projekt_id': 6394,
#    'acro': nan,
#    'title': 'Karakterizacija lipidne kompozicije membrana stanica inficiranih citomegalovirusom',
#    'totalCost': 1066.6666666666667}),
#  (1481,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (1481,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (1481,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (1481,
#   6354,
#   {'projekt_id': 6719,
#    'acro': nan,
#    'title': 'Reciklirajući endosomalni putovi',
#    'totalCost': 23549.570666666667}),
#  (2186,
#   2220,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2186,
#   13564,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2186,
#   31037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2186,
#   33037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2186,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2186,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2186,
#   1265,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   1882,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   2213,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   2214,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   2913,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   34436,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38785,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38786,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38787,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38788,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38789,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38790,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38791,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   38792,
#   {'projekt_id': 4495,
#    'acro': 'CiMozak / CirBrain',
#    'title': 'Identification of circulating biomarkers for neuro-recovery  of brain-injured patients',
#    'totalCost': 151040.0}),
#  (2186,
#   30782,
#   {'projekt_id': 5691,
#    'acro': nan,
#    'title': 'Karakterizacija endotelne disfunkcije i uloga IL-18 u razvoju ishemijsko reperfuzijske ozljede nakon kirurške revaskularizacije miokarda',
#    'totalCost': 7102.3786666666665}),
#  (2186,
#   39240,
#   {'projekt_id': 5733,
#    'acro': nan,
#    'title': 'Izvanstanične vezikule kao klinički markeri neuroregeneracije nakon teške ozljede mozga',
#    'totalCost': 20468.108}),
#  (2186,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (2186,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (2220,
#   13564,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2220,
#   31037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2220,
#   33037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2220,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (2220,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (2220,
#   2584,
#   {'projekt_id': 5697,
#    'acro': nan,
#    'title': 'Rab10 u biogenezi endosomalnog reciklirajućeg odjeljka',
#    'totalCost': 10572.337333333333}),
#  (2220,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (2220,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (2220,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (2220,
#   6354,
#   {'projekt_id': 6719,
#    'acro': nan,
#    'title': 'Reciklirajući endosomalni putovi',
#    'totalCost': 23549.570666666667}),
#  (13564,
#   31037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (13564,
#   33037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (13564,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (13564,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (13564,
#   2584,
#   {'projekt_id': 5697,
#    'acro': nan,
#    'title': 'Rab10 u biogenezi endosomalnog reciklirajućeg odjeljka',
#    'totalCost': 10572.337333333333}),
#  (13564,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (13564,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (13564,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (13564,
#   3742,
#   {'projekt_id': 6786,
#    'acro': nan,
#    'title': 'Presječno istraživanje rožnične histereze u trudnoći',
#    'totalCost': 5760.0}),
#  (13564,
#   3877,
#   {'projekt_id': 6786,
#    'acro': nan,
#    'title': 'Presječno istraživanje rožnične histereze u trudnoći',
#    'totalCost': 5760.0}),
#  (13564,
#   34182,
#   {'projekt_id': 6786,
#    'acro': nan,
#    'title': 'Presječno istraživanje rožnične histereze u trudnoći',
#    'totalCost': 5760.0}),
#  (31037,
#   33037,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (31037,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (31037,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (31037,
#   8174,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   33457,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   34217,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   35313,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   38152,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   38153,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   38378,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   38950,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   38951,
#   {'projekt_id': 4756,
#    'acro': 'CoV2mAbs',
#    'title': 'No more hiding CoV-2: Establishment of SARS-Cov-2 mAbeom',
#    'totalCost': 199846.40266666666}),
#  (31037,
#   3328,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (31037,
#   39212,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (31037,
#   2584,
#   {'projekt_id': 5697,
#    'acro': nan,
#    'title': 'Rab10 u biogenezi endosomalnog reciklirajućeg odjeljka',
#    'totalCost': 10572.337333333333}),
#  (31037,
#   39462,
#   {'projekt_id': 6394,
#    'acro': nan,
#    'title': 'Karakterizacija lipidne kompozicije membrana stanica inficiranih citomegalovirusom',
#    'totalCost': 1066.6666666666667}),
#  (31037,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (31037,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (31037,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (31037,
#   6354,
#   {'projekt_id': 6719,
#    'acro': nan,
#    'title': 'Reciklirajući endosomalni putovi',
#    'totalCost': 23549.570666666667}),
#  (33037,
#   35073,
#   {'projekt_id': 7,
#    'acro': 'AsCo',
#    'title': 'Karakterizacija preuređivanja endosomalnih membrana tijekom rane faze infekcije mišjim citomegalovirusom koje vodi k formiranju kompleksa za stvaranje viriona',
#    'totalCost': 106218.13333333333}),
#  (33037,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (33037,
#   3328,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (33037,
#   39212,
#   {'projekt_id': 5690,
#    'acro': nan,
#    'title': 'Arf GTPaze u regulaciji endosomalnog prometovanja tijekom citomegalovirusne infekcije',
#    'totalCost': 11712.2}),
#  (33037,
#   28306,
#   {'projekt_id': 6383,
#    'acro': 'Arf & CMV',
#    'title': 'Stanični sustav Arf GTPaza u patogenezi citomegalovirusne infekcije',
#    'totalCost': 90533.33333333333}),
#  (33037,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (33037,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (33037,
#   2224,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   2904,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   18502,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   18626,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   20407,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   22970,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   26835,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   30068,
#   {'projekt_id': 6692,
#    'acro': nan,
#    'title': 'Uloga mikroRNA u nastanku oštećenja krvnih žila koje uzrokuje kronična bubrežna bolest',
#    'totalCost': 20418.028}),
#  (33037,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (35073,
#   19282,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   29154,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   32519,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   32844,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   35072,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   38712,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   38713,
#   {'projekt_id': 4446,
#    'acro': 'AsCoSE&E',
#    'title': 'Beta-herpesvirus secondary envelopment and egress',
#    'totalCost': 178791.66666666666}),
#  (35073,
#   2584,
#   {'projekt_id': 5697,
#    'acro': nan,
#    'title': 'Rab10 u biogenezi endosomalnog reciklirajućeg odjeljka',
#    'totalCost': 10572.337333333333}),
#  (35073,
#   26587,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (35073,
#   39436,
#   {'projekt_id': 6650,
#    'acro': nan,
#    'title': 'Endosomalni odjeljci u infekciji mišjim citomegalovirusom',
#    'totalCost': 50025.846666666665}),
#  (35073,
#   39625,
#   {'projekt_id': 6718,
#    'acro': nan,
#    'title': 'Karakterizacija kasnih endosomalnih odjeljaka i njihova uloga u morfogenezi MCMV-a',
#    'totalCost': 28069.280000000002}),
#  (6610,
#   9205,
#   {'projekt_id': 18,
#    'acro': 'TomGraf',
#    'title': 'Cijepljenje rajčice ublažava biotički stres izazvan štitastim moljcima',
#    'totalCost': 92732.66666666667}),
#  (6610,
#   10819,
#   {'projekt_id': 18,
#    'acro': 'TomGraf',
#    'title': 'Cijepljenje rajčice ublažava biotički stres izazvan štitastim moljcima',
#    'totalCost': 92732.66666666667}),
#  (6610,
#   5397,
#   {'projekt_id': 2960,
#    'acro': 'AnGEL',
#    'title': 'Anisakis spp: genomska epidemiologija',
#    'totalCost': 132666.66666666666}),
#  (6610,
#   665,
#   {'projekt_id': 3645,
#    'acro': 'CAKUT',
#    'title': 'Karakterizacija kandidat gena za kongenitalne anomalije bubrega i urotrakta (CAKUT) tijekom razvoja u miša i čovjeka',
#    'totalCost': 133333.33333333334}),
#  (6610,
#   18977,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   30446,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   19342,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   30338,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   28912,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   33097,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   10550,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   6611,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   30752,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   26640,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   907,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   28395,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   12962,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   25563,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   587,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   34179,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   39142,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   18590,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   4356,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   2862,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   28913,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   26611,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   1616,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   29000,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   477,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   30578,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   4359,
#   {'projekt_id': 5497,
#    'acro': nan,
#    'title': 'Internacionalizacija diplomskih studijskih programa na Prirodoslovno-matematičkom fakultetu u Splitu',
#    'totalCost': 237457.188}),
#  (6610,
#   32436,
#   {'projekt_id': 5497,
#    'acro': nan,
# ...
#    'totalCost': 116246.66666666667}),
#  (6456,
#   34826,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (6456,
#   36139,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (6456,
#   38050,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (6456,
#   2161,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   5269,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   5640,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   6665,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   16268,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   17814,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   25819,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   27941,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   30194,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   32435,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   32768,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   33320,
#   {'projekt_id': 63,
#    'acro': 'ProtModStruct',
#    'title': 'Esencijalni metalni ioni u proteinima iz Heliobacter pylori i modelnim spojevima-struktura u funkcija/svojstvo',
#    'totalCost': 129333.33333333333}),
#  (6456,
#   37155,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (6456,
#   38765,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (31878,
#   33319,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (31878,
#   34826,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (31878,
#   36139,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (31878,
#   38050,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (31878,
#   37155,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (31878,
#   38765,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (33319,
#   34826,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (33319,
#   36139,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (33319,
#   38050,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (33319,
#   37155,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (33319,
#   38765,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (34826,
#   36139,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (34826,
#   38050,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (34826,
#   37155,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (34826,
#   38765,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (36139,
#   38050,
#   {'projekt_id': 48,
#    'acro': 'CrystEngMOM',
#    'title': 'Kristalno inženjerstvo višekomponentinih metaloorganksih materijala povezanih halogenskom vezom: ususret supramolekulskom ugađanju strukture i svojstava',
#    'totalCost': 116246.66666666667}),
#  (36139,
#   37155,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (36139,
#   38765,
#   {'projekt_id': 4484,
#    'acro': 'HaloBond',
#    'title': 'Nove građevne jedinke u supramolekulskom dizajnu složenih višekomponentnih molekulskih kristala temeljenih na halogenskim vezama',
#    'totalCost': 131586.66666666666}),
#  (18344,
#   31343,
#   {'projekt_id': 49,
#    'acro': 'HI-WI',
#    'title': 'Holografija i interferometrija u uvjetima niske razine svjetlosti',
#    'totalCost': 128933.33333333333}),
#  (18344,
#   33202,
#   {'projekt_id': 49,
#    'acro': 'HI-WI',
#    'title': 'Holografija i interferometrija u uvjetima niske razine svjetlosti',
#    'totalCost': 128933.33333333333}),
#  (18344,
#   6425,
#   {'projekt_id': 553,
#    'acro': nan,
#    'title': 'Prosudba novih bioaktivnih materijala i postupaka u restaurativnoj dentalnoj medicini',
#    'totalCost': 177866.66666666666}),
#  (18344,
#   18925,
#   {'projekt_id': 553,
#    'acro': nan,
#    'title': 'Prosudba novih bioaktivnih materijala i postupaka u restaurativnoj dentalnoj medicini',
#    'totalCost': 177866.66666666666}),
#  (31343,
#   33202,
#   {'projekt_id': 49,
#    'acro': 'HI-WI',
#    'title': 'Holografija i interferometrija u uvjetima niske razine svjetlosti',
#    'totalCost': 128933.33333333333}),
#  (31343,
#   3807,
#   {'projekt_id': 60,
#    'acro': 'SAALP',
#    'title': 'Potraga za aksiomima i njima sličnim česticama',
#    'totalCost': 44613.333333333336}),
#  (1102,
#   1228,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   1852,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   3767,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   4298,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   5066,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   18635,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   27267,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   29138,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   29432,
#   {'projekt_id': 52,
#    'acro': 'ZOTONanoPhotovolt',
#    'title': 'Nanokompoziti cinkovog oksida i titanijevog dioksida za fotonaponsku primjenu',
#    'totalCost': 89573.06666666667}),
#  (1102,
#   880,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   2987,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   7947,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   24422,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   27031,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   28806,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   31659,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   32353,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   33238,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   33624,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   34239,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   35180,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   35401,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   36207,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   38436,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   38437,
#   {'projekt_id': 3924,
#    'acro': 'NanoPeroPhotoSens',
#    'title': 'Nanokompoziti s perovskitima za fotovoltaike, fotokatalizu i senzoriku',
#    'totalCost': 197404.66666666666}),
#  (1102,
#   1747,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  (1102,
#   2835,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  (1102,
#   3184,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  (1102,
#   3365,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  (1102,
#   3538,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  (1102,
#   3764,
#   {'projekt_id': 4613,
#    'acro': 'OS-Mi',
#    'title': 'Otpad i Sunce u službi fotokatalitičke razgradnje mikroonečišćivala u vodama',
#    'totalCost': 1130866.3933333333}),
#  ...]

# %%
person = 29951 # 29951 daria, 38162 nikola, 10389 mile, 7101 ALONE, 2667 soldo
centered = nx.Graph(nx.ego_graph(G, person, radius = 2))

# %%
Gt = trim_nodes(centered,100)
print ('Number of nodes: ', Gt.order())
print ('Number of edges: ', Gt.size())
# Out:
# Number of nodes:  9
# Number of edges:  35

# %%
net = G

# %%
'''This is a measure of how complete the graph is (how many edges are present 
in the network as compared to the total possible number of edges).'''

density = nx.density(net)

print('The edge density is: ' + str(density))
# Out:
# The edge density is: 0.001487476794950405

# %%
'''This is a common centrality measure, which gives an idea of how 'imporant' each node 
is in the network. The assumption is that nodes with the most edges are the most 
important/central as they are directly connected to lots of other nodes. Nodes with a 
high centrality might be expected to play important roles in network. '''

#the degree function in networkx returns a DegreeView object capable of iterating through (node, degree) pairs
degree = net.degree()

degree_list = []

for (n,d) in degree:
    degree_list.append(d)

av_degree = sum(degree_list) / len(degree_list)

print('The average degree is ' + str(av_degree))
# Out:
# The average degree is 15.132101435030469

# %%
# distribution of the degree
plt.figure(2)
d = nx.degree_histogram(net)
plt.hist(d,bins=15)
plt.show()

# %%
centrality = nx.degree_centrality(net)
btwncnt = nx.betweenness_centrality(net)

# %%
pos = nx.spring_layout(net)

plt.figure(2,figsize=(15,10))
plt.axis("off")
# draw graph
nx.draw_networkx_nodes(net, pos=pos, alpha=0.5, node_size=100, node_color='green')
nx.draw_networkx_edges(net, pos=pos, alpha=0.3)
#nx.draw_networkx_edge_labels(net, pos=pos, edge_labels=nx.get_edge_attributes(net,'projekt_id'))

# draw subgraph for highlights
nx.draw_networkx(net.subgraph(person), pos=pos, node_size=2000, node_color='red', 
                 font_family='sans-serif', font_weight='bold', font_size=12, font_color='black')
#nx.draw_networkx(net.subgraph(38162), pos=pos, node_size=1200, node_color='orange', 
#                font_family='sans-serif', font_weight='bold', font_size=12, font_color='black')

# most important
net_important = most_important(centered) # trimming
nx.draw_networkx_nodes(net_important, pos=pos, alpha=0.9, node_size=1000, node_color='pink')
nx.draw_networkx_labels(net_important, pos=pos, alpha=0.8, 
                        font_family='sans-serif', font_weight='normal', font_size=10, font_color='black')

plt.show()

# %%
# Uses Louvain algorithm - References large networks. J. Stat. Mech 10008, 1-12(2008).
partition = community_louvain.best_partition(net)

# color the nodes according to their partition
plt.figure(2,figsize=(15,10))
plt.axis("off")
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(net, pos, partition.keys(), 
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(net, pos, alpha=0.5)
plt.show()

# %%
# https://notebook.community/eflegara/NetStruc/6.%20Community%20Detection
import operator
## For Hierarchical Clustering
## from scipy.cluster import hierarchy
## from scipy.spatial import distance

#order the dictionary by value, which is the edge betweeness of two nodes
ebet = nx.edge_betweenness_centrality(net)
sorted_ebet = sorted(ebet.items(), key=operator.itemgetter(1), reverse=True)
sorted_ebet[0:5]
# Out:
# [((29951, 38162), 0.02215962764434843),
#  ((10389, 2427), 0.016342499066494435),
#  ((10389, 514), 0.015406604304798465),
#  ((10389, 10457), 0.0103009110463129),
#  ((10389, 2043), 0.009505618980498334)]
